# %%
import pandas as pd

# %%
data = pd.read_csv('myDataFile.csv')

# %%
data
# Out:
#     p_num                 age_group   correlation
# 0       1  participant_rsv129es.mat -1.426569e-04
# 1       2  participant_rsv145es.mat  1.090411e-05
# 2       3  participant_rsv147es.mat -1.088604e-04
# 3       4  participant_rsv148es.mat -1.274953e-04
# 4       5  participant_rsv149es.mat -8.373497e-06
# 5       6  participant_rsv150es.mat -2.772436e-04
# 6       7  participant_rsv151es.mat -8.403665e-05
# 7       8  participant_rsv152es.mat -2.360272e-04
# 8       9  participant_rsv153es.mat -2.521407e-04
# 9      10  participant_rsv155es.mat -3.007096e-04
# 10     11  participant_rsv156es.mat  5.599273e-05
# 11     12  participant_rsv157es.mat -7.753143e-05
# 12     13  participant_rsv159es.mat -8.109920e-05
# 13     14  participant_rsv160es.mat -2.166206e-04
# 14     15  participant_rsv161es.mat -1.519531e-04
# 15     16  participant_rsv162es.mat -2.120231e-05
# 16     17  participant_rsv163es.mat -1.753363e-04
# 17     18  participant_rsv166es.mat  1.439137e-05
# ...
